# %% [markdown]
# ### SUPERVISED LEARNING ON HOUSE RENT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import LabelEncoder , MinMaxScaler
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
df.info() 
df.isnull().sum()# We don't have missing data here and that's great
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# min       1.000000     0.000000     0.000000     1.000000   370.000000
# 25%       1.000000     0.000000     0.000000     3.000000  1190.000000
# 50%       1.500000     0.000000     0.000000     3.000000  1590.000000
# 75%       2.000000     0.000000     0.000000     4.000000  2300.000000
# max       3.500000     1.000000     4.000000     5.000000  9410.000000
#
#        sqft_basement     yr_built  yr_renovated
# count    4600.000000  4600.000000   4600.000000
# mean      312.081522  1970.786304    808.608261
# std       464.137228    29.731848    979.414536
# min         0.000000  1900.000000      0.000000
# 25%         0.000000  1951.000000      0.000000
# 50%         0.000000  1976.000000      0.000000
# 75%       610.000000  1997.000000   1999.000000
# max      4820.000000  2014.000000   2014.000000

# %% [markdown]
# Encoding (dealing with catagorical data)

# %%
# The city where the house is located could provide valuable information on 
# regional price differences.
print(df.city.nunique())
df['city'].value_counts()
# Out:
# 44
# city
# Seattle                1573
# Renton                  293
# Bellevue                286
# Redmond                 235
# Issaquah                187
# Kirkland                187
# Kent                    185
# Auburn                  176
# Sammamish               175
# Federal Way             148
# Shoreline               123
# Woodinville             115
# Maple Valley             96
# Mercer Island            86
# Burien                   74
# Snoqualmie               71
# Kenmore                  66
# Des Moines               58
# North Bend               50
# Covington                43
# Duvall                   42
# Lake Forest Park         36
# Bothell                  33
# Newcastle                33
# SeaTac                   29
# Tukwila                  29
# Vashon                   29
# Enumclaw                 28
# Carnation                22
# Normandy Park            18
# Clyde Hill               11
# Medina                   11
# Fall City                11
# Black Diamond             9
# Ravensdale                7
# Pacific                   6
# Algona                    5
# Yarrow Point              4
# Skykomish                 3
# Preston                   2
# Milton                    2
# Inglewood-Finn Hill       1
# Snoqualmie Pass           1
# Beaux Arts Village        1
# Name: count, dtype: int64

# %%
df['statezip'].nunique()
# Out:
# 77

# %%
#city_counts = df['city'].value_counts()
#df['city_freq_encoded'] = df['city'].map(city_counts)
le_model = LabelEncoder()
df['city'] = le_model.fit_transform(df['city'])
df['statezip'] = le_model.fit_transform(df['statezip'])

# %%
# Convert the 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year
df['Age_of_the_House'] = df['year'] - df['yr_built']

# %%
# We will drop the object columns that may not help us in our model 
# Note : all the data are in the USA so the country is unmeaningful
df.drop(columns=['country','street','date','year'] , inplace= True)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), cmap="RdBu")
plt.title("Correlations Between Variables", size=15)
plt.show()

# %%
#So we can see from this graph that the price increase between May and June slowly than ,
# it increases between June and July
print(df['month'].value_counts())
plt.xticks(np.arange(5,8,1))
df.groupby('month').mean()['price'].plot()
plt.ylabel('price')
# Out:
# month
# 6    2179
# 5    1768
# 7     653
# Name: count, dtype: int64
# Text(0, 0.5, 'price')

# %%
# From the heatmap (correlation graph) we will drop the month column as 
#it has a bad correlation with the other features
df.drop(columns=['month'], inplace=True)
df.dtypes # Now model can deal with this dataset easily,as we don't have any object column
# Out:
# price               float64
# bedrooms            float64
# bathrooms           float64
# sqft_living           int64
# sqft_lot              int64
# floors              float64
# waterfront            int64
# view                  int64
# condition             int64
# sqft_above            int64
# sqft_basement         int64
# yr_built              int64
# yr_renovated          int64
# city                  int32
# statezip              int32
# Age_of_the_House      int64
# dtype: object

# %% [markdown]
# ## Data Visualization

# %%
important_num_cols = list(df.corr()["price"][(df.corr()["price"]>0.20) | (df.corr()["price"]<-0.20)].index)
sns.pairplot(df[important_num_cols])

# %%
sns.countplot(x=df['bedrooms']) #Almost houses have 3 and 4 bedrooms
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
sns.displot(df['price'])

# %%
#The square footage of living space is a fundamental feature affecting house prices.
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(20,10))
sns.boxenplot(data = df)
plt.xticks(rotation=90)
plt.show()     # Removing outliers here affected badly on the the result of r2_score
               # So I keep it.

# %%
#price against waterfall
print(df['waterfront'].value_counts())
plt.figure(figsize=(12,8))
sns.boxenplot(x='waterfront',y='price',data=df)
# Out:
# waterfront
# 0    4567
# 1      33
# Name: count, dtype: int64
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
x = df.drop('price',axis=1)
y= df[['price']]

# %%
scaler = MinMaxScaler()
x = scaler.fit_transform(x)
y = scaler.fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y , test_size=0.2 ,random_state=50)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3680, 15)
# (3680, 1)
# (920, 15)
# (920, 1)

# %% [markdown]
# #  ANN model structure

# %%
from tensorflow.keras.optimizers import Adam
model = Sequential([
    Dense(10,activation='relu' , input_dim= 15),
    Dense(10, activation= 'relu'),
    Dense(10, activation= 'relu'),
    Dense(1 , activation= 'linear')
])

model.compile(optimizer=Adam(0.001) , loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 391 (1.53 KB)
#  Trainable params: 391 (1.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, batch_size=30, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.0080 - val_loss: 5.9538e-04
# Epoch 2/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0011 - val_loss: 4.1257e-04
# Epoch 3/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.2059e-04 - val_loss: 3.0816e-04
# Epoch 4/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.7331e-04 - val_loss: 2.5460e-04
# Epoch 5/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.9839e-04 - val_loss: 2.1765e-04
# Epoch 6/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.9627e-04 - val_loss: 2.3928e-04
# Epoch 7/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.2894e-04 - val_loss: 1.7370e-04
# Epoch 8/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.3554e-04 - val_loss: 1.5238e-04
# Epoch 9/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.2947e-04 - val_loss: 1.3623e-04
# Epoch 10/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6731e-04 - val_loss: 1.3300e-04
# Epoch 11/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.6575e-04 - val_loss: 1.2273e-04
# Epoch 12/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.1009e-04 - val_loss: 1.5621e-04
# Epoch 13/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.0040e-04 - val_loss: 1.2385e-04
# Epoch 14/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.0907e-04 - val_loss: 1.4485e-04
# Epoch 15/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.9480e-04 - val_loss: 1.3317e-04
# Epoch 16/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.8878e-04 - val_loss: 1.0863e-04
# Epoch 17/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.3010e-04 - val_loss: 1.0870e-04
# Epoch 18/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.2703e-04 - val_loss: 1.4133e-04
# Epoch 19/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0015 - val_loss: 1.2510e-04
# Epoch 20/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.8040e-04 - val_loss: 1.1898e-04
# Epoch 21/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.0162e-04 - val_loss: 1.4210e-04
# Epoch 22/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.0416e-04 - val_loss: 1.3435e-04
# Epoch 23/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.6146e-04 - val_loss: 1.0245e-04
# Epoch 24/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.0352e-04 - val_loss: 1.4534e-04
# Epoch 25/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.3392e-04 - val_loss: 1.0755e-04
# Epoch 26/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.2596e-04 - val_loss: 1.0532e-04
# Epoch 27/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.4965e-04 - val_loss: 1.0400e-04
# Epoch 28/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.2926e-04 - val_loss: 1.3733e-04
# Epoch 29/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.7187e-04 - val_loss: 1.0382e-04
# Epoch 30/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0011 - val_loss: 9.6905e-05
# Epoch 31/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.2026e-04 - val_loss: 1.0396e-04
# Epoch 32/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.7706e-04 - val_loss: 1.3336e-04
# Epoch 33/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.6879e-04 - val_loss: 1.0986e-04
# Epoch 34/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.3424e-04 - val_loss: 1.1982e-04
# Epoch 35/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.1650e-04 - val_loss: 1.0635e-04
# Epoch 36/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.1930e-04 - val_loss: 9.9601e-05
# Epoch 37/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.1187e-04 - val_loss: 9.6879e-05
# Epoch 38/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2862e-04 - val_loss: 1.3174e-04
# Epoch 39/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0013 - val_loss: 1.2871e-04
# Epoch 40/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.4657e-04 - val_loss: 1.0311e-04
# Epoch 41/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.2071e-04 - val_loss: 9.6745e-05
# Epoch 42/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.8990e-04 - val_loss: 9.4817e-05
# Epoch 43/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.0538e-04 - val_loss: 1.0030e-04
# Epoch 44/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.2343e-04 - val_loss: 1.3957e-04
# Epoch 45/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.0573e-04 - val_loss: 9.7289e-05
# Epoch 46/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.1884e-04 - val_loss: 1.0017e-04
# Epoch 47/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.7382e-04 - val_loss: 1.1787e-04
# Epoch 48/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.8254e-04 - val_loss: 1.8401e-04
# Epoch 49/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.4261e-04 - val_loss: 1.3671e-04
# Epoch 50/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.8051e-04 - val_loss: 1.3066e-04
# Epoch 51/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012 - val_loss: 9.7639e-05
# Epoch 52/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.8815e-04 - val_loss: 9.6611e-05
# Epoch 53/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.5020e-04 - val_loss: 2.0767e-04
# Epoch 54/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.3312e-04 - val_loss: 9.9794e-05
# Epoch 55/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.1098e-04 - val_loss: 1.3950e-04
# Epoch 56/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.4397e-04 - val_loss: 1.0239e-04
# Epoch 57/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.1272e-04 - val_loss: 3.9329e-04
# Epoch 58/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.7106e-04 - val_loss: 1.1741e-04
# Epoch 59/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.2304e-04 - val_loss: 1.0013e-04
# Epoch 60/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.1787e-04 - val_loss: 1.1830e-04
# Epoch 61/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.6556e-04 - val_loss: 9.8712e-05
# Epoch 62/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.2088e-04 - val_loss: 9.6869e-05
# Epoch 63/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0011 - val_loss: 9.7679e-05
# Epoch 64/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.7045e-04 - val_loss: 9.5623e-05
# Epoch 65/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.4941e-04 - val_loss: 1.2320e-04
# Epoch 66/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.9438e-04 - val_loss: 9.6864e-05
# Epoch 67/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.2149e-04 - val_loss: 9.6495e-05
# Epoch 68/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.5459e-04 - val_loss: 1.1639e-04
# Epoch 69/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.1690e-04 - val_loss: 9.6741e-05
# Epoch 70/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.0277e-04 - val_loss: 1.0799e-04
# Epoch 71/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.1322e-04 - val_loss: 1.0399e-04
# Epoch 72/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.9762e-04 - val_loss: 9.9427e-05
# Epoch 73/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.6382e-04 - val_loss: 9.7090e-05
# Epoch 74/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.6464e-04 - val_loss: 9.8202e-05
# Epoch 75/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.5086e-04 - val_loss: 1.0575e-04
# Epoch 76/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.0050e-04 - val_loss: 1.8860e-04
# Epoch 77/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6703e-04 - val_loss: 1.0866e-04
# Epoch 78/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.5457e-04 - val_loss: 9.8609e-05
# Epoch 79/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.9018e-04 - val_loss: 9.9864e-05
# Epoch 80/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.0288e-04 - val_loss: 1.0471e-04
# Epoch 81/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 2.5458e-04 - val_loss: 1.4239e-04
# Epoch 82/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.4032e-04 - val_loss: 9.7919e-05
# Epoch 83/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1814e-04 - val_loss: 1.0110e-04
# Epoch 84/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0012 - val_loss: 1.0061e-04
# Epoch 85/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.7036e-04 - val_loss: 9.9642e-05
# Epoch 86/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.2830e-04 - val_loss: 1.0006e-04
# Epoch 87/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.6172e-04 - val_loss: 9.7728e-05
# Epoch 88/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5453e-04 - val_loss: 9.6455e-05
# Epoch 89/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1673e-04 - val_loss: 9.8219e-05
# Epoch 90/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.1992e-04 - val_loss: 1.0187e-04
# Epoch 91/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9507e-04 - val_loss: 1.0256e-04
# Epoch 92/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1321e-04 - val_loss: 1.1377e-04
# Epoch 93/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8664e-04 - val_loss: 9.9537e-05
# Epoch 94/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9796e-04 - val_loss: 9.6662e-05
# Epoch 95/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2899e-04 - val_loss: 9.7625e-05
# Epoch 96/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8571e-04 - val_loss: 9.8893e-05
# Epoch 97/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.6647e-04 - val_loss: 1.0128e-04
# Epoch 98/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.4938e-04 - val_loss: 1.1807e-04
# Epoch 99/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.1062e-04 - val_loss: 9.8630e-05
# Epoch 100/100
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.6850e-04 - val_loss: 1.3483e-04

# %%
# Define needed variables
tr_loss = history.history['loss']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

Epochs = [i+1 for i in range(len(tr_loss))]
loss_label = f'best epoch= {str(index_loss + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)

plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout
plt.show()

# %%
y_pred = model.predict(x_test)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2)
# Out:
# R2 Score= 0.38508954040427557

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error



# Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)

# Root Mean Squared Error
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 0.00011073460879116987
# Mean Absolute Error: 0.0079987021207017
# Root Mean Squared Error: 0.01052305130611696
